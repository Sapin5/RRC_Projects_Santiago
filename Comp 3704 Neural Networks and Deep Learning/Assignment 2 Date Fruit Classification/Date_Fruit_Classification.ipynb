# %% [markdown]
# #Assignment 2: Date Fruit Classification
# ## COMP-3704 (241552) Neural Networks and Deep Learning
#
# ###Brandon, Santiago

# %%
# Importting libraries
import pandas as pd
import seaborn as sns
import numpy as np
import tensorflow as tf
import sklearn.metrics as skm
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import MinMaxScaler as mms
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import LabelEncoder
from pprint import pprint as pp

# %%
# Importing data
df = pd.read_csv("Date_Fruit_Datasets.csv")
df.head()
# Out:
#      AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0  422163   2378.908    837.8484    645.6693        0.6373  733.1539
# 1  338136   2085.144    723.8198    595.2073        0.5690  656.1464
# 2  526843   2647.394    940.7379    715.3638        0.6494  819.0222
# 3  416063   2351.210    827.9804    645.2988        0.6266  727.8378
# 4  347562   2160.354    763.9877    582.8359        0.6465  665.2291
#
#    SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# 0    0.9947       424428  0.7831        1.2976  ...      3.2370      2.9574
# 1    0.9974       339014  0.7795        1.2161  ...      2.6228      2.6350
# 2    0.9962       528876  0.7657        1.3150  ...      3.7516      3.8611
# 3    0.9948       418255  0.7759        1.2831  ...      5.0401      8.6136
# 4    0.9908       350797  0.7569        1.3108  ...      2.7016      2.9761
#
#    KurtosisRB     EntropyRR    EntropyRG    EntropyRB  ALLdaub4RR  ALLdaub4RG  \
# 0      4.2287 -5.919126e+10 -50714214400 -39922372608     58.7255     54.9554
# 1      3.1704 -3.423307e+10 -37462601728 -31477794816     50.0259     52.8168
# 2      4.7192 -9.394835e+10 -74738221056 -60311207936     65.4772     59.2860
# 3      8.2618 -3.207431e+10 -32060925952 -29575010304     43.3900     44.1259
# 4      4.4146 -3.998097e+10 -35980042240 -25593278464     52.7743     50.9080
#
#    ALLdaub4RB  Class
# 0     47.8400  BERHI
# 1     47.8315  BERHI
# 2     51.9378  BERHI
# 3     41.1882  BERHI
# 4     42.6666  BERHI
#
# [5 rows x 35 columns]

# %%
# Displaying data statistics
df.describe()
# Out:
#                 AREA    PERIMETER   MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY  \
# count     898.000000   898.000000   898.000000  898.000000    898.000000
# mean   298295.207127  2057.660953   750.811994  495.872785      0.737468
# std    107245.205337   410.012459   144.059326  114.268917      0.088727
# min      1987.000000   911.828000   336.722700    2.283200      0.344800
# 25%    206948.000000  1726.091500   641.068650  404.684375      0.685625
# 50%    319833.000000  2196.345450   791.363400  495.054850      0.754700
# 75%    382573.000000  2389.716575   858.633750  589.031700      0.802150
# max    546063.000000  2811.997100  1222.723000  766.453600      1.000000
#
#           EQDIASQ    SOLIDITY    CONVEX_AREA      EXTENT  ASPECT_RATIO  ...  \
# count  898.000000  898.000000     898.000000  898.000000    898.000000  ...
# mean   604.577938    0.981840  303845.592428    0.736267      2.131102  ...
# std    119.593888    0.018157  108815.656947    0.053745     17.820778  ...
# min     50.298400    0.836600    2257.000000    0.512300      1.065300  ...
# 25%    513.317075    0.978825  210022.750000    0.705875      1.373725  ...
# 50%    638.140950    0.987300  327207.000000    0.746950      1.524150  ...
# 75%    697.930525    0.991800  388804.000000    0.775850      1.674750  ...
# max    833.827900    0.997400  552598.000000    0.856200    535.525700  ...
#
#            SkewRB  KurtosisRR  KurtosisRG  KurtosisRB     EntropyRR  \
# count  898.000000  898.000000  898.000000  898.000000  8.980000e+02
# mean     0.250518    4.247845    5.110894    3.780928 -3.185021e+10
# std      0.632918    2.892357    3.745463    2.049831  2.037241e+10
# min     -1.029100    1.708200    1.607600    1.767200 -1.091220e+11
# 25%     -0.196950    2.536625    2.508850    2.577275 -4.429444e+10
# 50%      0.135550    3.069800    3.127800    3.080700 -2.826156e+10
# 75%      0.593950    4.449850    7.320400    4.283125 -1.460482e+10
# max      3.092300   26.171100   26.736700   32.249500 -1.627316e+08
#
#           EntropyRG     EntropyRB  ALLdaub4RR  ALLdaub4RG  ALLdaub4RB
# count  8.980000e+02  8.980000e+02  898.000000  898.000000  898.000000
# mean  -2.901860e+10 -2.771876e+10   50.082888   48.805681   48.098393
# std    1.712952e+10  1.484137e+10   16.063125   14.125911   10.813862
# min   -9.261697e+10 -8.747177e+10   15.191100   20.524700   22.130000
# 25%   -3.894638e+10 -3.564534e+10   38.224425   38.654525   39.250725
# 50%   -2.620990e+10 -2.392928e+10   53.841300   50.337800   49.614100
# 75%   -1.433105e+10 -1.660367e+10   63.063350   59.573600   56.666675
# max   -5.627727e+08 -4.370435e+08   79.828900   83.064900   74.104600
#
# [8 rows x 34 columns]

# %% [markdown]
# These features represent the 34 subfeatures of the main three features, which are Morphological features, Shape features, and Colour features.
#
# The subfeatures of Morphological features are:
#
# Area,	Equivalent diameter, Perimeter,	Solidity, Major axis,	Convex_area, Minor axis,	Extent, Eccentricity,	Aspect ratio, Roundness, Compactness
#
# The subfeatures of Shape features are:
#
# Shapefactor_1, Shapefactor_3, Shapefactor_2, Shapefactor_4,
#
# The subfeatures of Colours features are:
#
# Mean RR, Mean RG, Mean RR,
# Std. dev RR, Std. dev RG, Std. dev RR,
# Skew RR,	Skew RG, Skew RR,
# Kurtosis RR, Kurtosis RG, Kurtosis RR,
# Entropy RR, Entropy RG,	Entropy RR,
# All Daub4 RR,	All Daub4 RG,	All Daub4 RR

# %%
# Displayng data types and nan count
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 898 entries, 0 to 897
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AREA           898 non-null    int64
#  1   PERIMETER      898 non-null    float64
#  2   MAJOR_AXIS     898 non-null    float64
#  3   MINOR_AXIS     898 non-null    float64
#  4   ECCENTRICITY   898 non-null    float64
#  5   EQDIASQ        898 non-null    float64
#  6   SOLIDITY       898 non-null    float64
#  7   CONVEX_AREA    898 non-null    int64
#  8   EXTENT         898 non-null    float64
#  9   ASPECT_RATIO   898 non-null    float64
#  10  ROUNDNESS      898 non-null    float64
#  11  COMPACTNESS    898 non-null    float64
#  12  SHAPEFACTOR_1  898 non-null    float64
#  13  SHAPEFACTOR_2  898 non-null    float64
#  14  SHAPEFACTOR_3  898 non-null    float64
#  15  SHAPEFACTOR_4  898 non-null    float64
#  16  MeanRR         898 non-null    float64
#  17  MeanRG         898 non-null    float64
#  18  MeanRB         898 non-null    float64
#  19  StdDevRR       898 non-null    float64
#  20  StdDevRG       898 non-null    float64
#  21  StdDevRB       898 non-null    float64
#  22  SkewRR         898 non-null    float64
#  23  SkewRG         898 non-null    float64
#  24  SkewRB         898 non-null    float64
#  25  KurtosisRR     898 non-null    float64
#  26  KurtosisRG     898 non-null    float64
#  27  KurtosisRB     898 non-null    float64
#  28  EntropyRR      898 non-null    float64
#  29  EntropyRG      898 non-null    int64
#  30  EntropyRB      898 non-null    int64
#  31  ALLdaub4RR     898 non-null    float64
#  32  ALLdaub4RG     898 non-null    float64
#  33  ALLdaub4RB     898 non-null    float64
#  34  Class          898 non-null    object
# dtypes: float64(30), int64(4), object(1)
# memory usage: 245.7+ KB

# %%
# Counting duplicates
duplicates = df.duplicated()
dupe_count = duplicates.sum()
print('There are', dupe_count, 'duplicates')

# Dropping duplicates
df.drop_duplicates(inplace=True)
# Out:
# There are 0 duplicates

# %% [markdown]
# There were no missing values in any of the columns.
#
# There also appeared to be no duplicated values.
#
# We dropped duplicated values anyways just incase

# %%
# Plotting elements in each category
plt.figure(figsize=(8,6))
sns.set(style='darkgrid')
sns.countplot(data=df, x='Class')
plt.title('Elements in each category')
# Out:
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Elements in each category')

# %% [markdown]
# The data set is fairly balanced, however three columns stand out the most when commpared to the others. As they have many more counts in them than the others, this may effect the model.

# %%
# Splitting data into labels and features
labels = df[['Class']]
features = df.drop(columns='Class')

# %%
# Scaling data
scaler = mms()
features = scaler.fit_transform(features)

label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)
# Out:
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Santiago Pinto\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Reshaping labels into 2D array
labels = np.reshape(labels, (-1, 1))

# %%
# Splitting data into train test validation split
x_train, x_remaining, y_train, y_remaining = tts(features, labels, test_size = 0.3, random_state=42)

x_test, x_val, y_test, y_val = tts(x_remaining, y_remaining, test_size = 0.5, random_state=42)

# %% [markdown]
# ## 2 Modeling

# %% [markdown]
# ### Model 1

# %%
# Creating first model
model_1 = tf.keras.Sequential()

# Input layer
model_1.add(tf.keras.Input(shape=34))

# Hidden layers
model_1.add(tf.keras.layers.Dense(50, activation='relu'))
model_1.add(tf.keras.layers.Dense(100, activation='tanh'))

# Output layer
model_1.add(tf.keras.layers.Dense(7, activation='softmax'))

# Loss funciton for compiler
loss = tf.keras.losses.SparseCategoricalCrossentropy()

# Optimizer for Compiler
optimizer = tf.keras.optimizers.Adam()

# Compiler
model_1.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

# Fitting training data and running 100 epochs
model_1.fit(x_train, y_train, epochs = 100
          , verbose = 1, validation_data = (x_test,y_test))

# Displaying model summary
model_1.summary()
# Out:
# Epoch 1/100
#  1/20 [>.............................] - ETA: 7s - loss: 1.9240 - accuracy: 0.2812
# 20/20 [==============================] - 1s 7ms/step - loss: 1.7446 - accuracy: 0.4411 - val_loss: 1.4779 - val_accuracy: 0.5704
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4006 - accuracy: 0.6210 - val_loss: 1.1693 - val_accuracy: 0.6741
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1186 - accuracy: 0.6258 - val_loss: 0.9201 - val_accuracy: 0.7037
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9124 - accuracy: 0.6417 - val_loss: 0.7774 - val_accuracy: 0.7481
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7784 - accuracy: 0.7277 - val_loss: 0.6736 - val_accuracy: 0.7926
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.7516 - val_loss: 0.6155 - val_accuracy: 0.8296
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6198 - accuracy: 0.7882 - val_loss: 0.5623 - val_accuracy: 0.8444
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5643 - accuracy: 0.8057 - val_loss: 0.5086 - val_accuracy: 0.8296
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5234 - accuracy: 0.8280 - val_loss: 0.4930 - val_accuracy: 0.8444
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4941 - accuracy: 0.8328 - val_loss: 0.4770 - val_accuracy: 0.8519
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4579 - accuracy: 0.8503 - val_loss: 0.4211 - val_accuracy: 0.8741
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4351 - accuracy: 0.8519 - val_loss: 0.4112 - val_accuracy: 0.8519
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4242 - accuracy: 0.8615 - val_loss: 0.3696 - val_accuracy: 0.8741
# Epoch 14/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4059 - accuracy: 0.8678 - val_loss: 0.3822 - val_accuracy: 0.8741
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.8742 - val_loss: 0.3510 - val_accuracy: 0.8815
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3710 - accuracy: 0.8774 - val_loss: 0.3551 - val_accuracy: 0.8667
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3639 - accuracy: 0.8710 - val_loss: 0.3311 - val_accuracy: 0.8741
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3589 - accuracy: 0.8869 - val_loss: 0.3264 - val_accuracy: 0.8741
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3455 - accuracy: 0.8838 - val_loss: 0.3168 - val_accuracy: 0.8741
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3342 - accuracy: 0.
100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1790 - accuracy: 0.9395 - val_loss: 0.2211 - val_accuracy: 0.9185
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1814 - accuracy: 0.9331 - val_loss: 0.2184 - val_accuracy: 0.9185
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1798 - accuracy: 0.9331 - val_loss: 0.2065 - val_accuracy: 0.9185
# Epoch 97/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1786 - accuracy: 0.9331 - val_loss: 0.2093 - val_accuracy: 0.9259
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1715 - accuracy: 0.9363 - val_loss: 0.1965 - val_accuracy: 0.9259
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1724 - accuracy: 0.9411 - val_loss: 0.2315 - val_accuracy: 0.9111
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1706 - accuracy: 0.9347 - val_loss: 0.1980 - val_accuracy: 0.9407
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                1750
#
#  dense_1 (Dense)             (None, 100)               5100
#
#  dense_2 (Dense)             (None, 7)                 707
#
# =================================================================
# Total params: 7557 (29.52 KB)
# Trainable params: 7557 (29.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Seperating loss and accuracy into individual variables
train_loss_m1, train_acc_m1 = model_1.evaluate(x_train, y_train, verbose=0)

# Predicting training data for confusion matrix
predict_m1 = np.argmax(model_1.predict(x_train, verbose=0), axis=1)

# Creating confusion matrix
cm_m1 = confusion_matrix(predict_m1, y_train)

print('This model was the first attempt at creating a model'
      + '\nSo it uses 1 input layer, the fist hidden layer with 50 neurons and relu activation functions\n'
      + 'The second hidden layer uses 100 nuerons and tanh activation\n'
      + 'The output layer has 7 neurons and uses the softmax activation function.\n'
      + 'It uses the Adam optimzer and SparseCategoricalCrossentropy loss\n')

# Printing loss and accuracy
print('Loss on training set:', train_loss_m1
      ,'\nAccuracy on training set:', train_acc_m1, '\n')

# Plotting confusion matrix
disp_1 = ConfusionMatrixDisplay(confusion_matrix=cm_m1)
disp_1.plot()
# Out:
# This model was the first attempt at creating a model
# So it uses 1 input layer, the fist hidden layer with 50 neurons and relu activation functions
# The second hidden layer uses 100 nuerons and tanh activation
# The output layer has 7 neurons and uses the softmax activation function.
# It uses the Adam optimzer and SparseCategoricalCrossentropy loss
#
# Loss on training set: 0.1674419492483139
# Accuracy on training set: 0.9442675113677979

# %% [markdown]
# ### Model 2

# %%
# Creating second matrix
model_2 = tf.keras.Sequential()

# Input layer
model_2.add(tf.keras.Input(shape=34))

# Hidden layers
model_2.add(tf.keras.layers.Dense(40, activation='relu'))
model_2.add(tf.keras.layers.Dense(50, activation='sigmoid'))
model_2.add(tf.keras.layers.Dense(100, activation='sigmoid'))
model_2.add(tf.keras.layers.Dense(130, activation='relu'))

# Output layers
model_2.add(tf.keras.layers.Dense(7, activation='softmax'))

# Loss funciton for compiler
loss = tf.keras.losses.SparseCategoricalCrossentropy()

# Optimizer for compiler
optimizer = tf.keras.optimizers.Lion()

# Compiling model
model_2.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

# Fitting training data and running 100 epochs
model_2.fit(x_train, y_train, epochs = 100
          , verbose = 1, validation_data = (x_test,y_test))

# Displaying model summary
model_2.summary()
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 6ms/step - loss: 2.0034 - accuracy: 0.1369 - val_loss: 1.9434 - val_accuracy: 0.2296
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8949 - accuracy: 0.2357 - val_loss: 1.8369 - val_accuracy: 0.2296
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8575 - accuracy: 0.2484 - val_loss: 1.7941 - val_accuracy: 0.2296
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8613 - accuracy: 0.2580 - val_loss: 1.7891 - val_accuracy: 0.2741
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5914 - accuracy: 0.7787 - val_loss: 0.5575 - val_accuracy: 0.7704
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5809 - accuracy: 0.7803 - val_loss: 0.5451 - val_accuracy: 0.7852
# Epoch 79/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5728 - accuracy: 0.7803 - val_loss: 0.5385 - val_accuracy: 0.7852
# Epoch 80/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5628 - accuracy: 0.7818 - val_loss: 0.5289 - val_accuracy: 0.7926
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5556 - accuracy: 0.7962 - val_loss: 0.5139 - val_accuracy: 0.7926
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5458 - accuracy: 0.7930 - val_loss: 0.5049 - val_accuracy: 0.7926
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5370 - accuracy: 0.7882 - val_loss: 0.5058 - val_accuracy: 0.7926
# Epoch 84/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5292 - accuracy: 0.7898 - val_loss: 0.4981 - val_accuracy: 0.7926
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5210 - accuracy: 0.7914 - val_loss: 0.4877 - val_accuracy: 0.8000
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5134 - accuracy: 0.7962 - val_loss: 0.4887 - val_accuracy: 0.8000
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5058 - accuracy: 0.8057 - val_loss: 0.4773 - val_accuracy: 0.7926
# Epoch 88/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4984 - accuracy: 0.7946 - val_loss: 0.4669 - val_accuracy: 0.7926
# Epoch 89/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4933 - accuracy: 0.8089 - val_loss: 0.4649 - val_accuracy: 0.8000
# Epoch 90/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4856 - accuracy: 0.8121 - val_loss: 0.4589 - val_accuracy: 0.8000
# Epoch 91/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4791 - accuracy: 0.8073 - val_loss: 0.4516 - val_accuracy: 0.7926
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4737 - accuracy: 0.8089 - val_loss: 0.4532 - val_accuracy: 0.7852
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4674 - accuracy: 0.8121 - val_loss: 0.4485 - val_accuracy: 0.7778
# Epoch 94/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4626 - accuracy: 0.8137 - val_loss: 0.4441 - val_accuracy: 0.7852
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4567 - accuracy: 0.8232 - val_loss: 0.4384 - val_accuracy: 0.7852
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4524 - accuracy: 0.8264 - val_loss: 0.4356 - val_accuracy: 0.7926
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4477 - accuracy: 0.8105 - val_loss: 0.4272 - val_accuracy: 0.8000
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4436 - accuracy: 0.8248 - val_loss: 0.4256 - val_accuracy: 0.8000
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4407 - accuracy: 0.8185 - val_loss: 0.4204 - val_accuracy: 0.7926
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4362 - accuracy: 0.8296 - val_loss: 0.4163 - val_accuracy: 0.8000
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 40)                1400
#
#  dense_4 (Dense)             (None, 50)                2050
#
#  dense_5 (Dense)             (None, 100)               5100
#
#  dense_6 (Dense)             (None, 130)               13130
#
#  dense_7 (Dense)             (None, 7)                 917
#
# =================================================================
# Total params: 22597 (88.27 KB)
# Trainable params: 22597 (88.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Seperating loss and accuracy into individual variables
train_loss_m2, train_acc_m2 = model_2.evaluate(x_train, y_train, verbose=0)

# Predicting training data for confusion matrix
predict_m2 = np.argmax(model_2.predict(x_train, verbose=0), axis=1)
cm_m2 = confusion_matrix(predict_m2, y_train)

print('This model was made with the idea of adding more layers and trying multiple activation\n'
      + 'The fist hidden layer with 40 neurons and relu activation functions\n'
      + 'The second hidden layer uses 50 nuerons and sigmoid activation\n'
      + 'The third hidden layer uses 100 nuerons and sigmoid activation\n'
      + 'The fourth hidden layer uses 130 nuerons and relu activation\n'
      + 'The output layer has 7 neurons and uses the softmax activation function.\n'
      + 'It makes use of the Lion optimzer and SparseCategoricalCrossentropy for loss once again\n')

# Creating confusion matrix
print('Loss on training set:', train_loss_m2
      ,'\nAccuracy on training set:', train_acc_m2, '\n')

# Plotting confusion matrix
disp_2 = ConfusionMatrixDisplay(confusion_matrix=cm_m2)
disp_2.plot()
# Out:
# This model was made with the idea of adding more layers and trying multiple activation
# The fist hidden layer with 40 neurons and relu activation functions
# The second hidden layer uses 50 nuerons and sigmoid activation
# The third hidden layer uses 100 nuerons and sigmoid activation
# The fourth hidden layer uses 130 nuerons and relu activation
# The output layer has 7 neurons and uses the softmax activation function.
# It makes use of the Lion optimzer and SparseCategoricalCrossentropy for loss once again
#
# Loss on training set: 0.43022623658180237
# Accuracy on training set: 0.8296178579330444

# %% [markdown]
# ### Model 3

# %%
# Creating model 3
model_3 = tf.keras.Sequential()

# Input layer
model_3.add(tf.keras.Input(shape=34))

# Hidden layers
model_3.add(tf.keras.layers.Dense(20, activation='sigmoid'))
model_3.add(tf.keras.layers.Dense(40, activation='relu'))
model_3.add(tf.keras.layers.Dense(70, activation='sigmoid'))

# Output layer
model_3.add(tf.keras.layers.Dense(7, activation='softmax'))


# Loss function for compiler
loss = tf.keras.losses.Poisson()

# Optimzer for compiler
optimizer = tf.keras.optimizers.Adam()

# Complining model
model_3.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

# Fitting training data and running it for 100 epochs
model_3.fit(x_train, y_train, epochs = 100
          , verbose = 1, validation_data = (x_test,y_test))

# Displaying model summary
model_3.summary()
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 5ms/step - loss: 6.5659 - accuracy: 0.1417 - val_loss: 6.6414 - val_accuracy: 0.0593
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5265 - accuracy: 0.0780 - val_loss: 6.6310 - val_accuracy: 0.1926
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5234 - accuracy: 0.1354 - val_loss: 6.6295 - val_accuracy: 0.1185
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5230 - accuracy: 0.1640 - val_loss: 6.6294 - val_accuracy: 0.0889
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5230 - accuracy: 0.0955 - val_loss: 6.6294 - val_accuracy: 0.0889
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.0908 - val_loss: 6.6293 - val_accuracy: 0.1111
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.0828 - val_loss: 6.6293 - val_accuracy: 0.1111
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.0955 - val_loss: 6.6293 - val_accuracy: 0.1111
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.0876 - val_loss: 6.6293 - val_accuracy: 0.1111
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.0924 - val_loss: 6.6293 - val_accuracy: 0.0963
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.0780 - val_loss: 6.6293 - val_accuracy: 0.1333
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.0844 - val_loss: 6.6293 - val_accuracy: 0.1037
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.0764 - val_loss: 6.6293 - val_accuracy: 0.0963
# Epoch 14/100
# 20/20 [==============================] - 0s 1ms/step - loss: 6.5229 - accuracy: 0.0812 - val_loss: 6.6293 - val_accuracy: 0.0963
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.0955 - val_loss: 6.6293 - val_accuracy: 0.1259
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.0908 - val_loss: 6.6293 - val_accuracy: 0.1259
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.0971 - val_loss: 6.6292 - val_accuracy: 0.1259
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.1194 - val_loss: 6.6292 - val_accuracy: 0.1259
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.1194 - val_loss: 6.6292 - val_accuracy: 0.1481
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.1306 - val_loss: 6.6292 - val_accuracy: 0.1704
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.1178 - val_loss: 6.6292 - val_accuracy: 0.1259
# Epoch 22/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.1369 - val_loss: 6.6292 - val_accuracy: 0.1407
# Epoch 23/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5229 - accuracy: 0.1258 - val_loss: 6.6292 - val_accuracy: 0.1407
# Epoch 24/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1354 - val_loss: 6.6292 - val_accuracy: 0.1556
# Epoch 25/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1258 - val_loss: 6.6292 - val_accuracy: 0.1704
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1306 - val_loss: 6.6292 - val_accuracy: 0.0889
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1449 - val_loss: 6.6292 - val_accuracy: 0.1037
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1258 - val_loss: 6.6292 - val_accuracy: 0.0963
# Epoch 79/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1322 - val_loss: 6.6292 - val_accuracy: 0.1407
# Epoch 80/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1529 - val_loss: 6.6292 - val_accuracy: 0.0963
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1465 - val_loss: 6.6292 - val_accuracy: 0.1111
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1449 - val_loss: 6.6292 - val_accuracy: 0.0815
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1433 - val_loss: 6.6292 - val_accuracy: 0.1037
# Epoch 84/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1274 - val_loss: 6.6292 - val_accuracy: 0.1481
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1274 - val_loss: 6.6292 - val_accuracy: 0.1556
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1513 - val_loss: 6.6292 - val_accuracy: 0.1481
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1545 - val_loss: 6.6292 - val_accuracy: 0.0889
# Epoch 88/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1401 - val_loss: 6.6292 - val_accuracy: 0.0741
# Epoch 89/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1306 - val_loss: 6.6292 - val_accuracy: 0.1037
# Epoch 90/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1497 - val_loss: 6.6292 - val_accuracy: 0.1407
# Epoch 91/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1290 - val_loss: 6.6292 - val_accuracy: 0.1185
# Epoch 92/100
# 20/20 [==============================] - 0s 1ms/step - loss: 6.5228 - accuracy: 0.1401 - val_loss: 6.6292 - val_accuracy: 0.1111
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1465 - val_loss: 6.6292 - val_accuracy: 0.1111
# Epoch 94/100
# 20/20 [==============================] - 0s 1ms/step - loss: 6.5228 - accuracy: 0.1449 - val_loss: 6.6292 - val_accuracy: 0.0889
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1338 - val_loss: 6.6292 - val_accuracy: 0.1926
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1545 - val_loss: 6.6292 - val_accuracy: 0.1630
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1465 - val_loss: 6.6292 - val_accuracy: 0.1037
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1576 - val_loss: 6.6292 - val_accuracy: 0.0741
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1433 - val_loss: 6.6292 - val_accuracy: 0.1037
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5228 - accuracy: 0.1417 - val_loss: 6.6292 - val_accuracy: 0.1407
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 20)                700
#
#  dense_9 (Dense)             (None, 40)                840
#
#  dense_10 (Dense)            (None, 70)                2870
#
#  dense_11 (Dense)            (None, 7)                 497
#
# =================================================================
# Total params: 4907 (19.17 KB)
# Trainable params: 4907 (19.17 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Seperating loss and accuracy into individual variables
train_loss_m3, train_acc_m3 = model_3.evaluate(x_train, y_train, verbose=0)

# Predicting training data for confusion matrix
predict_m3 = np.argmax(model_3.predict(x_train, verbose=0), axis=1)
cm_m3 = confusion_matrix(predict_m3, y_train)

print('This model was made with the idea of using a different loss function\n'
      + 'The fist hidden layer with 20 neurons and sigmoid activation functions\n'
      + 'The second hidden layer uses 40 nuerons and relu activation\n'
      + 'The third hidden layer uses 70 nuerons and sigmoid activation\n'
      + 'The output layer has 7 neurons and uses the softmax activation function.\n'
      + 'It makes use of the adam optimzer and Poisson for loss once again\n')

# Creating confusion matrix
print('Loss on training set:', train_loss_m3
      ,'\nAccuracy on training set:', train_acc_m3, '\n')

# Ploting confusion matrix
disp_3 = ConfusionMatrixDisplay(confusion_matrix=cm_m3)
disp_3.plot()
# Out:
# This model was made with the idea of using a different loss function
# The fist hidden layer with 20 neurons and sigmoid activation functions
# The second hidden layer uses 40 nuerons and relu activation
# The third hidden layer uses 70 nuerons and sigmoid activation
# The output layer has 7 neurons and uses the softmax activation function.
# It makes use of the adam optimzer and Poisson for loss once again
#
# Loss on training set: 6.52284049987793
# Accuracy on training set: 0.15445859730243683

# %% [markdown]
# ### Model 4

# %%
# Creating model 4
model_4 = tf.keras.Sequential()

# Input layer
model_4.add(tf.keras.Input(shape=34))

# Hidden layers
model_4.add(tf.keras.layers.Dense(34, activation='sigmoid'))
model_4.add(tf.keras.layers.Dense(67, activation='tanh'))
model_4.add(tf.keras.layers.Dense(85, activation='sigmoid'))
model_4.add(tf.keras.layers.Dense(120, activation='relu'))
model_4.add(tf.keras.layers.Dense(40, activation='tanh'))
model_4.add(tf.keras.layers.Dense(185, activation='relu'))

# output layers
model_4.add(tf.keras.layers.Dense(7, activation='softmax'))

# Loss function for compiler
loss = tf.keras.losses.SparseCategoricalCrossentropy()

# Optimzer for compiler
optimizer = tf.keras.optimizers.Lion()

# Compling model
model_4.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

# Fitting data
model_4.fit(x_train, y_train, epochs = 100
          , verbose = 1, validation_data = (x_test,y_test))

# Displaying model summary
model_4.summary()
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9697 - accuracy: 0.1290 - val_loss: 1.9154 - val_accuracy: 0.1926
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.9031 - accuracy: 0.2022 - val_loss: 1.8553 - val_accuracy: 0.2296
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8715 - accuracy: 0.2357 - val_loss: 1.8215 - val_accuracy: 0.2296
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8574 - accuracy: 0.2357 - val_loss: 1.8006 - val_accuracy: 0.2296
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8549 - accuracy: 0.2420 - val_loss: 1.7939 - val_accuracy: 0.5037
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8563 - accuracy: 0.2261 - val_loss: 1.7957 - val_accuracy: 0.2741
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8532 - accuracy: 0.2325 - val_loss: 1.7999 - val_accuracy: 0.5037
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8491 - accuracy: 0.2834 - val_loss: 1.8019 - val_accuracy: 0.2296
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8452 - accuracy: 0.2357 - val_loss: 1.7962 - val_accuracy: 0.2296
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8394 - accuracy: 0.3455 - val_loss: 1.7848 - val_accuracy: 0.4296
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8330 - accuracy: 0.3901 - val_loss: 1.7752 - val_accuracy: 0.3185
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8247 - accuracy: 0.3217 - val_loss: 1.7627 - val_accuracy: 0.4148
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8116 - accuracy: 0.4363 - val_loss: 1.7511 - val_accuracy: 0.3852
# Epoch 14/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7938 - accuracy: 0.3710 - val_loss: 1.7323 - val_accuracy: 0.4148
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7702 - accuracy: 0.4268 - val_loss: 1.7076 - val_accuracy: 0.4444
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7398 - accuracy: 0.4363 - val_loss: 1.6702 - val_accuracy: 0.4667
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7008 - accuracy: 0.4395 - val_loss: 1.6261 - val_accuracy: 0.4667
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.6551 - accuracy: 0.4379 - val_loss: 1.5755 - val_accuracy: 0.4815
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.6057 - accuracy: 0.4427 - val_loss: 1.5237 - val_accuracy: 0.4815
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5495 - accuracy: 0.4427 - val_loss: 1.4642 - val_accuracy: 0.4963
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4936 - accuracy: 0.4459 - val_loss: 1.4078 - val_accuracy: 0.4815
# Epoch 22/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4365 - accuracy: 0.4475 - val_loss: 1.3512 - val_accuracy: 0.4963
# Epoch 23/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3826 - accuracy: 0.4475 - val_loss: 1.3033 - val_accuracy: 0.4963
# Epoch 24/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 34)                1190
#
#  dense_13 (Dense)            (None, 67)                2345
#
#  dense_14 (Dense)            (None, 85)                5780
#
#  dense_15 (Dense)            (None, 120)               10320
#
#  dense_16 (Dense)            (None, 40)                4840
#
#  dense_17 (Dense)            (None, 185)               7585
#
#  dense_18 (Dense)            (None, 7)                 1302
#
# =================================================================
# Total params: 33362 (130.32 KB)
# Trainable params: 33362 (130.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
train_loss_m4, train_acc_m4 = model_4.evaluate(x_train, y_train, verbose=0)

predict_m4 = np.argmax(model_4.predict(x_train, verbose=0), axis=1)
cm_m4 = confusion_matrix(predict_m4, y_train)

print('This model was made with the idea of using many more nodes than necessary\n'
      + 'The fist hidden layer with 34 neurons and sigmoid activation functions\n'
      + 'The second hidden layer uses 67 nuerons and tanh activation\n'
      + 'The third hidden layer uses 85 nuerons and sigmoid activation\n'
      + 'The fourth hidden layer with 120 neurons and relu activation functions\n'
      + 'The fifth hidden layer uses 40 nuerons and tanh activation\n'
      + 'The sixth hidden layer uses 185 nuerons and sigmoid activation\n'
      + 'The output layer has 7 neurons and uses the softmax activation function.\n'
      + 'It makes use of the Lion optimzer and SparseCategoricalCrossentropy for loss\n')


print('Loss on training set:', train_loss_m4
      ,'\nAccuracy on training set:', train_acc_m4, '\n')

disp_4 = ConfusionMatrixDisplay(confusion_matrix=cm_m4)
disp_4.plot()
# Out:
# This model was made with the idea of using many more nodes than necessary
# The fist hidden layer with 34 neurons and sigmoid activation functions
# The second hidden layer uses 67 nuerons and tanh activation
# The third hidden layer uses 85 nuerons and sigmoid activation
# The fourth hidden layer with 120 neurons and relu activation functions
# The fifth hidden layer uses 40 nuerons and tanh activation
# The sixth hidden layer uses 185 nuerons and sigmoid activation
# The output layer has 7 neurons and uses the softmax activation function.
# It makes use of the Lion optimzer and SparseCategoricalCrossentropy for loss
#
# Loss on training set: 0.3415256142616272
# Accuracy on training set: 0.8694267272949219

# %% [markdown]
# ### Model 5

# %%
model_5 = tf.keras.Sequential()
model_5.add(tf.keras.Input(shape=34))
model_5.add(tf.keras.layers.Dense(20, activation='tanh'))
model_5.add(tf.keras.layers.Dense(40, activation='tanh'))
model_5.add(tf.keras.layers.Dense(40, activation='relu'))
model_5.add(tf.keras.layers.Dense(7, activation='softmax'))

loss = tf.keras.losses.SparseCategoricalCrossentropy()

optimizer = tf.keras.optimizers.Lion()

model_5.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

model_5.fit(x_train, y_train, epochs = 100
          , verbose = 1, validation_data = (x_test,y_test))

model_5.summary()
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9333 - accuracy: 0.2548 - val_loss: 1.8944 - val_accuracy: 0.2296
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8824 - accuracy: 0.2357 - val_loss: 1.8442 - val_accuracy: 0.2296
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8399 - accuracy: 0.2357 - val_loss: 1.8021 - val_accuracy: 0.2296
# Epoch 4/100
# 20/20 [==============================] - 0s 1ms/step - loss: 1.8023 - accuracy: 0.2357 - val_loss: 1.7651 - val_accuracy: 0.2296
# Epoch 5/100
# 20/20 [==============================] - 0s 1ms/step - loss: 1.7695 - accuracy: 0.2357 - val_loss: 1.7292 - val_accuracy: 0.2296
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7418 - accuracy: 0.2436 - val_loss: 1.6971 - val_accuracy: 0.2519
# Epoch 7/100
# 20/20 [==============================] - 0s 1ms/step - loss: 1.7125 - accuracy: 0.2898 - val_loss: 1.6650 - val_accuracy: 0.3481
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.
# Epoch 70/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3950 - accuracy: 0.8455 - val_loss: 0.3721 - val_accuracy: 0.8667
# Epoch 71/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3889 - accuracy: 0.8487 - val_loss: 0.3655 - val_accuracy: 0.8667
# Epoch 72/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3835 - accuracy: 0.8503 - val_loss: 0.3620 - val_accuracy: 0.8667
# Epoch 73/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3780 - accuracy: 0.8599 - val_loss: 0.3614 - val_accuracy: 0.8519
# Epoch 74/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3734 - accuracy: 0.8583 - val_loss: 0.3556 - val_accuracy: 0.8593
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3683 - accuracy: 0.8631 - val_loss: 0.3481 - val_accuracy: 0.8593
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3643 - accuracy: 0.8615 - val_loss: 0.3424 - val_accuracy: 0.8593
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3602 - accuracy: 0.8583 - val_loss: 0.3332 - val_accuracy: 0.8667
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3543 - accuracy: 0.8615 - val_loss: 0.3276 - val_accuracy: 0.8667
# Epoch 79/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3512 - accuracy: 0.8646 - val_loss: 0.3244 - val_accuracy: 0.8593
# Epoch 80/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3474 - accuracy: 0.8678 - val_loss: 0.3201 - val_accuracy: 0.8741
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.8694 - val_loss: 0.3188 - val_accuracy: 0.8593
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3389 - accuracy: 0.8726 - val_loss: 0.3177 - val_accuracy: 0.8667
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3351 - accuracy: 0.8726 - val_loss: 0.3163 - val_accuracy: 0.8667
# Epoch 84/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3319 - accuracy: 0.8742 - val_loss: 0.3097 - val_accuracy: 0.8741
# Epoch 85/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3285 - accuracy: 0.8758 - val_loss: 0.3070 - val_accuracy: 0.8667
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3255 - accuracy: 0.8774 - val_loss: 0.2966 - val_accuracy: 0.8741
# Epoch 87/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3221 - accuracy: 0.8806 - val_loss: 0.2920 - val_accuracy: 0.8741
# Epoch 88/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3195 - accuracy: 0.8758 - val_loss: 0.2901 - val_accuracy: 0.8741
# Epoch 89/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3152 - accuracy: 0.8806 - val_loss: 0.2879 - val_accuracy: 0.8741
# Epoch 90/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3127 - accuracy: 0.8838 - val_loss: 0.2869 - val_accuracy: 0.8741
# Epoch 91/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3101 - accuracy: 0.8885 - val_loss: 0.2831 - val_accuracy: 0.8667
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3060 - accuracy: 0.8869 - val_loss: 0.2835 - val_accuracy: 0.8593
# Epoch 93/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3032 - accuracy: 0.8869 - val_loss: 0.2795 - val_accuracy: 0.8593
# Epoch 94/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3010 - accuracy: 0.8885 - val_loss: 0.2788 - val_accuracy: 0.8593
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2976 - accuracy: 0.8901 - val_loss: 0.2742 - val_accuracy: 0.8667
# Epoch 96/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2949 - accuracy: 0.8917 - val_loss: 0.2657 - val_accuracy: 0.8815
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2940 - accuracy: 0.8917 - val_loss: 0.2653 - val_accuracy: 0.8815
# Epoch 98/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2903 - accuracy: 0.8885 - val_loss: 0.2659 - val_accuracy: 0.8667
# Epoch 99/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2883 - accuracy: 0.8901 - val_loss: 0.2689 - val_accuracy: 0.8741
# Epoch 100/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2851 - accuracy: 0.8949 - val_loss: 0.2633 - val_accuracy: 0.8815
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 20)                700
#
#  dense_20 (Dense)            (None, 40)                840
#
#  dense_21 (Dense)            (None, 40)                1640
#
#  dense_22 (Dense)            (None, 7)                 287
#
# =================================================================
# Total params: 3467 (13.54 KB)
# Trainable params: 3467 (13.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
train_loss_m5, train_acc_m5 = model_5.evaluate(x_train, y_train, verbose=0)

predict_m5 = np.argmax(model_5.predict(x_train, verbose=0), axis=1)
cm_m5 = confusion_matrix(predict_m5, y_train)

print('This we just wanted to try having two hidden layers with the same amount of neurons\n'
      + 'The fist hidden layer with 20 neurons and tanh activation functions\n'
      + 'The second hidden layer uses 40 nuerons and tanh activation\n'
      + 'The third hidden layer uses 40 nuerons and relu activation\n'
      + 'It makes use of the Lion optimzer and SparseCategoricalCrossentropy for loss\n')

print('Loss on training set:', train_loss_m5
      ,'\nAccuracy on training set:', train_acc_m5, '\n')

disp_5 = ConfusionMatrixDisplay(confusion_matrix=cm_m5)
disp_5.plot()
# Out:
# This we just wanted to try having two hidden layers with the same amount of neurons
# The fist hidden layer with 20 neurons and tanh activation functions
# The second hidden layer uses 40 nuerons and tanh activation
# The third hidden layer uses 40 nuerons and relu activation
# It makes use of the Lion optimzer and SparseCategoricalCrossentropy for loss
#
# Loss on training set: 0.28061190247535706
# Accuracy on training set: 0.8980891704559326

# %% [markdown]
# ## 3 Conclusion

# %% [markdown]
# Model 1 appears to be the best of the 5 models created. On the training data it is the only model to get over 90% accuracy, it had 94.27%. The next closest is model 5 with 87.74% accuracy on the training set.
#
# Model 1 also had the lowest loss (0.16887956857681274), with the next closest being model 4 with a loss of 0.3193982243537903,

# %%
# Creating best model
model_1 = tf.keras.Sequential()

# Input layer
model_1.add(tf.keras.Input(shape=34))

# Hidden layes
model_1.add(tf.keras.layers.Dense(50, activation='relu'))
model_1.add(tf.keras.layers.Dense(100, activation='tanh'))

# Outpput layers
model_1.add(tf.keras.layers.Dense(7, activation='softmax'))

# Loss function for compiler
loss = tf.keras.losses.SparseCategoricalCrossentropy()

# Optimizer for compiler
optimizer = tf.keras.optimizers.Adam()

# compiling model
model_1.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

# Fitting model, training for 100 epochs
# set verbose to 0 to hide fit information
model_1.fit(x_train, y_train, epochs = 100
          , verbose = 0, validation_data = (x_test,y_test))

# Displaiynf model summary
model_1.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_23 (Dense)            (None, 50)                1750
#
#  dense_24 (Dense)            (None, 100)               5100
#
#  dense_25 (Dense)            (None, 7)                 707
#
# =================================================================
# Total params: 7557 (29.52 KB)
# Trainable params: 7557 (29.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Saving accuracy and loss for testing set
test_loss_m1, test_acc_m1 = model_1.evaluate(x_test, y_test, verbose=0)

# Saving accuracy and loss for validation set
val_loss_m1, val_acc_m1 = model_1.evaluate(x_val, y_val, verbose=0)

# Creating confusion matrix
predict_m1 = np.argmax(model_1.predict(x_val, verbose=0), axis=1)
cm_m1 = confusion_matrix(predict_m1, y_val)

# Displaying loss and accuracy
print('Loss on testing set:', test_loss_m1
      ,'\nAccuracy on testing set:', test_acc_m1
      ,'\n\nLoss on validation set:', val_loss_m1
      ,'\nAccuracy on validation set:', val_acc_m1, '\n')

# Printing out plot
disp_1 = ConfusionMatrixDisplay(confusion_matrix=cm_m1)
disp_1.plot()
# Out:
# Loss on testing set: 0.2281704545021057
# Accuracy on testing set: 0.9259259104728699
#
# Loss on validation set: 0.28731805086135864
# Accuracy on validation set: 0.8740741014480591

# %% [markdown]
# Model 1 performed fairly well, with accuracy on validation and testing data both being from 91-92. The loss on both sets has also stayed low with it being around 0.21 on both.
#
# Looking at the confusion matrix, the model only had 5 false positives and 7 false negatives
